# %%
#  1. LISTS

fruits = ['apple','banana','orange','grapes']
print("original list:",fruits)
print("first fruit:",fruits[0])
# Out:
# original list: ['apple', 'banana', 'orange', 'grapes']
# first fruit: apple

# %%
fruits.append('cherry')
print("After appending list:",fruits)
# Out:
# After appending list: ['apple', 'banana', 'orange', 'grapes', 'cherry']

# %%
fruits.remove('banana')
print("After removing list:",fruits)

print("number of fruits:",len(fruits))
# Out:
# After removing list: ['apple', 'orange', 'grapes', 'cherry']
# number of fruits: 4

# %%
#  2. TUPLES

dimensions = (10,20,30)
print("Tuple:",dimensions)
# Out:
# Tuple: (10, 20, 30)

# %%
print("Second element:", dimensions[1])
# Out:
# Second element: 20

# %%
#  3. SETS

unique_numbers = {1, 2, 3, 2, 1}
print("Set (no duplicates):", unique_numbers)
# Out:
# Set (no duplicates): {1, 2, 3}

# %%
unique_numbers.add(4)
print("After adding 4:", unique_numbers)
# Out:
# After adding 4: {1, 2, 3, 4}

# %%
unique_numbers.remove(2)
print("After removing 2:", unique_numbers)
# Out:
# After removing 2: {1, 3, 4}

# %%
set_a = {1, 2, 3}
set_b = {3, 4, 5}
print("Union:", set_a | set_b)
print("Intersection:", set_a & set_b)
print("Difference (A - B):", set_a - set_b)
# Out:
# Union: {1, 2, 3, 4, 5}
# Intersection: {3}
# Difference (A - B): {1, 2}

# %%
#  4. DICTIONARIES

student = {
    'name': 'Alice',
    'age': 21,
    'course': 'Python'
}
print("Dictionary:", student)
# Out:
# Dictionary: {'name': 'Alice', 'age': 21, 'course': 'Python'}

# %%
print("Student name:", student['name'])
# Out:
# Student name: Alice

# %%
student['grade'] = 'A'
print("After adding grade:", student)

del student['age']
print("After deleting age:", student)

for key, value in student.items():
    print(f"{key}: {value}")
# Out:
# After adding grade: {'name': 'Alice', 'age': 21, 'course': 'Python', 'grade': 'A'}
# After deleting age: {'name': 'Alice', 'course': 'Python', 'grade': 'A'}
# name: Alice
# course: Python
# grade: A

# %%
keys = ['id', 'name', 'marks']
values = [101, 'John', 88]
student_info = dict(zip(keys, values))
print("Student Info from zip:", student_info)
# Out:
# Student Info from zip: {'id': 101, 'name': 'John', 'marks': 88}
